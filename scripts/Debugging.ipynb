# %%
import numpy as np

# %%
V_fold = np.array([[18,-3.7559442],[40,-3.7220365],[56,-3.7488093],
                   [99,-3.7420332],[159,-3.7366056],[196,-3.7466816],
                   [288,-3.7449761],[344,-3.7430175],[475,-3.7441329],
                   [635,-3.7432986],[726,-3.7424881]])
Us_fold = np.array([[18,-3.7559432],[40,-3.7220358],[56,-3.7488084],
                    [99,-3.7420326],[159,-3.7366052],[196,-3.7466809],
                    [288,-3.7449756],[344,-3.7430169],[475,-3.7441322],
                    [635,-3.743298],[726,-3.7424875],[936,-3.7442529],
                    [1056,-3.7443126],[1323,-3.7432564],[1470,-3.7433841],
                    [1800,-3.7439049],[2176,-3.743438],[2384,-3.7435526],
                    [2835,-3.743664],[3078,-3.7434327]])
M_vals = np.array([[2,-3.532381],[6,-3.8567196],[8,-3.6474017],
                   [16,-3.8083212],[19,-3.7011793],[28,-3.7356113],
                   [35,-3.7131362],[40,-3.7289455],[56,-3.7511797],
                   [72,-3.7512691],[84,-3.7397959],[104,-3.7356682],
                   [112,-3.7369454],[145,-3.7491534],[165,-3.7454871],
                   [195,-3.7406703],[240,-3.7430179],[240,-3.7430179],
                   [328,-3.7452963],[328,-3.7452963],[408,-3.7431282],
                   [413,-3.7417485],[440,-3.7430144],[511,-3.7447758],
                   [624,-3.7429354],[624,-3.7429354],[741,-3.7434209],
                   [728,-3.7439217],[897,-3.7438675]])

# %%
V_conv = [[i[0],abs(i[1]+3.7436520909)] for i in V_fold]
Us_conv = [[i[0],abs(i[1]+3.7436520909)] for i in Us_fold]
M_conv = [[i[0],abs(i[1]+3.7436520909)] for i in M_vals]

# %%
V_conv
# Out:
# [[18.0, 0.012292109100000115],
#  [40.0, 0.021615590899999759],
#  [56.0, 0.0051572091000000597],
#  [99.0, 0.0016188909000001139],
#  [159.0, 0.0070464909000000908],
#  [196.0, 0.0030295091000001051],
#  [288.0, 0.0013240091000001897],
#  [344.0, 0.00063459089999984286],
#  [475.0, 0.00048080909999992372],
#  [635.0, 0.00035349089999980876],
#  [726.0, 0.0011639908999998561]]

# %%
Us_conv
# Out:
# [[18.0, 0.012291109099999975],
#  [40.0, 0.021616290899999946],
#  [56.0, 0.0051563091000002004],
#  [99.0, 0.0016194909000000202],
#  [159.0, 0.0070468908999998803],
#  [196.0, 0.0030288090999999184],
#  [288.0, 0.0013235091000001198],
#  [344.0, 0.00063519089999974909],
#  [475.0, 0.00048010910000018114],
#  [635.0, 0.00035409090000015908],
#  [726.0, 0.0011645908999997623],
#  [936.0, 0.00060080910000026577],
#  [1056.0, 0.00066050910000026164],
#  [1323.0, 0.00039569090000002305],
#  [1470.0, 0.00026799089999984815],
#  [1800.0, 0.00025280910000002876],
#  [2176.0, 0.00021409090000013009],
#  [2384.0, 9.9490899999832294e-05],
#  [2835.0, 1.1909099999929396e-05],
#  [3078.0, 0.00021939089999989392]]

# %%
M_conv
# Out:
# [[2.0, 0.21127109089999996],
#  [6.0, 0.11306750909999996],
#  [8.0, 0.096250390899999871],
#  [16.0, 0.064669109100000011],
#  [19.0, 0.042472790899999779],
#  [28.0, 0.0080407908999999833],
#  [35.0, 0.030515890899999842],
#  [40.0, 0.014706590899999927],
#  [56.0, 0.0075276090999998324],
#  [72.0, 0.0076170091000000717],
#  [84.0, 0.0038561909000001116],
#  [104.0, 0.0079838908999998459],
#  [112.0, 0.0067066908999997565],
#  [145.0, 0.005501309100000018],
#  [165.0, 0.0018350091000001179],
#  [195.0, 0.0029817908999998366],
#  [240.0, 0.0006341909000000534],
#  [240.0, 0.0006341909000000534],
#  [328.0, 0.0016442091000001824],
#  [328.0, 0.0016442091000001824],
#  [408.0, 0.00052389089999982374],
#  [413.0, 0.0019035909000000295],
#  [440.0, 0.00063769090000009854],
#  [511.0, 0.0011237091000002586],
#  [624.0, 0.00071669090000003877],
#  [624.0, 0.00071669090000003877],
#  [741.0, 0.00023119090000012221],
#  [728.0, 0.00026960910000006777],
#  [897.0, 0.0002154090999999525]]
